# %% [markdown]
# # This is a basic Starter Kernel for the New York City Taxi Fare Prediction Playground Competition
# Here we'll use a simple linear model based on the travel vector from the taxi's pickup location to dropoff location which predicts the `fare_amount` of each ride.
#
# This kernel uses some `pandas` and mostly `numpy` for the critical work.  There are many higher-level libraries you could use instead, for example `sklearn` or `statsmodels`.

# %%
# %pip install pandas


# Initial Python environment setup...
import pandas as pd # CSV file I/O (e.g. pd.read_csv)

train_df =  pd.read_csv('train.csv', nrows = 10_000_000)
train_df.dtypes
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.9/site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in ./.venv/lib/python3.9/site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.9/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install flaml

from flaml import AutoML
automl = AutoML()
automl.fit(X_train, y_train, task="regression", time_budget=60)
# Out:
# Collecting flaml
#   Downloading FLAML-2.1.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: NumPy>=1.17.0rc1 in ./.venv/lib/python3.9/site-packages (from flaml) (1.26.2)
# Downloading FLAML-2.1.1-py3-none-any.whl (295 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.2/295.2 kB 4.2 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: flaml
# Successfully installed flaml-2.1.1
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       2 from flaml import AutoML
#       3 automl = AutoML()
# ----> 4 automl.fit(X_train, y_train, task="classification", time_budget=60)
#
# NameError: name 'X_train' is not defined
